# %% [markdown]
# ## Smodeling

# %% [markdown]
# https://habr.com/ru/companies/ru_mts/articles/485980/
# https://causalml.readthedocs.io/en/latest/methodology.html#s-learner https://github.com/uber/causalml/tree/master/causalml/inference/meta

# %% [markdown]
# У катбуста рофл, что он при предикте делает переданный нампаевский массив неизменяемым (X_new.flags WRITEABLE : ставит False), поэтому хгбуст

# %%
from pathlib import Path
import sys
 
if sys.argv:
    sys.path.insert(0, str(Path('/Users/ogrobertino/UpliftModelingResearch/').resolve()))
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
parameters = {
    'iterations': (30, 70),
    'learning_rate': (0.01, 0.5),
    'depth': (4, 15)
}

# %%
from src.utils import get_paths_train_test, train_test_model
from src.factory import SModelFactory
from src.models.CausalML.Models import SModel
from tqdm import tqdm

configs = SModel.generate_config(count=1, **parameters)

for i in tqdm(range(len(configs)), desc="Training models"):
    train_test_model(ds_name='lazada', features_percent=100, factory=SModelFactory, config=configs[i])
# Out:
# Training models:   0%|                                     | 0/1 [00:00<?, ?it/s]
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/96
# Training models: 100%|█████████████████████████████| 1/1 [00:15<00:00, 15.83s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv

# %%
from src.global_params import BASE_PATH
import pandas as pd
table = pd.read_csv(BASE_PATH / "exps/stats.tsv", sep='\t')
table[table['Model'] == 'SModel']
# Out:
#      Model                Path Dataset  Features Percent  Latency (ms)  \
# 54  SModel  exps/lazada/100/57  lazada               100      0.014437
# 55  SModel  exps/lazada/100/58  lazada               100      0.018150
# 56  SModel  exps/lazada/100/59  lazada               100      0.016392
# 57  SModel  exps/lazada/100/60  lazada               100      0.020767
# 58  SModel  exps/lazada/100/61  lazada               100      0.018847
# 59  SModel  exps/lazada/100/62  lazada               100      0.019982
# 60  SModel  exps/lazada/100/63  lazada               100      0.014559
# 61  SModel  exps/lazada/100/64  lazada               100      0.018894
# 62  SModel  exps/lazada/100/65  lazada               100      0.024093
# 63  SModel  exps/lazada/100/67  lazada               100      0.015063
# 65  SModel  exps/lazada/100/68  lazada               100      0.029767
# 66  SModel  exps/lazada/100/69  lazada               100      0.023602
# 67  SModel  exps/lazada/100/70  lazada               100      0.014396
# 68  SModel  exps/lazada/100/71  lazada               100      0.016243
# 69  SModel  exps/lazada/100/72  lazada               100      0.014318
# 70  SModel  exps/lazada/100/73  lazada               100      0.017337
# 93  SModel  exps/lazada/100/96  lazada               100      0.029183
#
#     Binary Size (MB)  AUUC (test)  Precision@5  Precision@10  Precision@15  \
# 54          0.007349     0.499809     0.012600      0.005989      0.006687
# 55          4.330892     0.636206     0.008142      0.006747      0.008170
# 56          0.986451     0.564490     0.011365      0.008026      0.007519
# 57          1.575159     0.512578     0.019139      0.008830      0.007275
# 58          4.712287     0.686275     0.016806      0.012373      0.009203
# 59          0.093448     0.559973     0.012870      0.009659      0.007789
# 60          0.396589     0.641142     0.014849      0.008104      0.009114
# 61          3.827024     0.627747     0.011655      0.008736      0.008640
# 62          4.767306     0.578322     0.008656      0.009300      0.008484
# 63          0.108652     0.657829     0.009266      0.007457      0.008150
# 65          2.148864     0.506409     0.002995      0.005212      0.005154
# 66          0.251984     0.665167     0.016246      0.009209      0.008716
# 67          0.156192     0.561611     0.009724      0.006658      0.005775
# 68          0.884568     0.677089     0.015236      0.012252      0.010879
# 69          0.252868     0.584003     0.018533      0.007497      0.007239
# 70          3.323633     0.474065     0.011336      0.004152      0.004996
# 93          0.121993     0.586844     0.008476      0.005866      0.005930
#
#     Precision@20  Precision@25  Precision@50 Compressions
# 54      0.005989      0.005149      0.004340           {}
# 55      0.006747      0.007862      0.005456           {}
# 56      0.008026      0.006751      0.004651           {}
# 57      0.008830      0.006662      0.003538           {}
# 58      0.012373      0.008244      0.005928           {}
# 59      0.009659      0.007390      0.004347           {}
# 60      0.008104      0.007609      0.005619           {}
# 61      0.008736      0.007927      0.004992           {}
# 62      0.009300      0.008181      0.004489           {}
# 63      0.007457      0.006874      0.005621           {}
# 65      0.005212      0.005787      0.004025           {}
# 66      0.009209      0.008875      0.006149           {}
# 67      0.006658      0.006454      0.004418           {}
# 68      0.012252      0.009352      0.004683           {}
# 69      0.007497      0.006668      0.004293           {}
# 70      0.004152      0.004660      0.003884           {}
# 93      0.005866      0.005800      0.005237           {}

# %%
table.tail(5)
# Out:
#      Model                Path Dataset  Features Percent  Latency (ms)  \
# 90  TModel  exps/lazada/100/93  lazada               100      0.340289
# 91  TModel  exps/lazada/100/94  lazada               100      0.335516
# 92  TModel  exps/lazada/100/95  lazada               100      0.059551
# 93  SModel  exps/lazada/100/96  lazada               100      0.029183
# 94  TModel  exps/lazada/100/97  lazada               100      0.060034
#
#     Binary Size (MB)  AUUC (test)  Precision@5  Precision@10  Precision@15  \
# 90          5.851716     0.515102     0.012037      0.006514      0.004976
# 91          4.920990     0.506538     0.010309      0.005853      0.005832
# 92         15.731801     0.621811     0.008838      0.007589      0.006579
# 93          0.121993     0.586844     0.008476      0.005866      0.005930
# 94         54.043945     0.461269    -0.002724      0.005485      0.005803
#
#     Precision@20  Precision@25  Precision@50 Compressions
# 90      0.006514      0.003477      0.003918           {}
# 91      0.005853      0.006273      0.003340           {}
# 92      0.007589      0.005857      0.004556           {}
# 93      0.005866      0.005800      0.005237           {}
# 94      0.005485      0.006601      0.003238           {}

# %%
# from src.models.ICausalML.Models import SModel
# path = pd.read_csv(BASE_PATH / "exps/stats.tsv", sep='\t').Path.iloc[-1]
# model = SModel(from_load=True, path = str(BASE_PATH) + "/" + path)
