# %% [markdown]
# ## CLASS TRANSFORMATION (REVERT LABELING)

# %% [markdown]
# https://habr.com/ru/companies/ru_mts/articles/485976/
#
# https://www.uplift-modeling.com/en/latest/user_guide/models/revert_label.html

# %%
from pathlib import Path
import sys
 
if sys.argv:
    sys.path.insert(0, str(Path('/Users/ogrobertino/UpliftModelingResearch/').resolve()))
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
parameters = {
    'iterations': (10, 25),
    'learning_rate': (0.01, 0.5),
    'depth': (4, 15)
}

# %%
from src.models.ScikitML.Models import ClassTransformationModel

# %%
from src.utils import get_paths_train_test, train_test_model
from src.factory import ClassTransformationFactory
from src.models.ScikitML.Models import ClassTransformationModel
from tqdm import tqdm

configs = ClassTransformationModel.generate_config(count=2, **parameters)

for i in tqdm(range(len(configs)), desc="Training models"):
    train_test_model(ds_name='lazada', features_percent=100, factory=ClassTransformationFactory, config=configs[i])
# Out:
# Training models:   0%|                                     | 0/2 [00:00<?, ?it/s]
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/104
# Training models:  50%|██████████████▌              | 1/2 [00:11<00:11, 11.80s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/105
# Training models: 100%|█████████████████████████████| 2/2 [00:21<00:00, 10.62s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv

# %%
from src.global_params import BASE_PATH
import pandas as pd
table = pd.read_csv(BASE_PATH / "exps/stats.tsv", sep='\t')
table[table['Model'] == 'ClassTransformationModel']
# Out:
#                         Model                 Path Dataset  Features Percent  \
# 99   ClassTransformationModel  exps/lazada/100/102  lazada               100
# 100  ClassTransformationModel  exps/lazada/100/103  lazada               100
# 101  ClassTransformationModel  exps/lazada/100/104  lazada               100
# 102  ClassTransformationModel  exps/lazada/100/105  lazada               100
#
#      Latency (ms)  Binary Size (MB)  AUUC (test)  Precision@5  Precision@10  \
# 99       0.040759          0.061043     0.270447     0.000463     -0.000636
# 100      0.040985         13.127252     0.283212     0.000544      0.001069
# 101      0.039428          1.322932     0.271519    -0.000864      0.000433
# 102      0.039581          0.118772     0.264293     0.000131      0.000694
#
#      Precision@15  Precision@20  Precision@25  Precision@50 Compressions
# 99       0.000404     -0.000636      0.000532      0.002035           {}
# 100      0.001156      0.001069      0.001054      0.001691           {}
# 101      0.000770      0.000433      0.000452      0.001726           {}
# 102      0.000733      0.000694      0.001249      0.001358           {}

# %%
table
# Out:
#                         Model                 Path Dataset  Features Percent  \
# 0                      TModel    exps/lazada/100/0  lazada               100
# 1                      TModel    exps/lazada/100/1  lazada               100
# 2                      TModel    exps/lazada/100/2  lazada               100
# 3                      TModel    exps/lazada/100/3  lazada               100
# 4                      TModel    exps/lazada/100/4  lazada               100
# ..                        ...                  ...     ...               ...
# 98                    DRModel  exps/lazada/100/101  lazada               100
# 99   ClassTransformationModel  exps/lazada/100/102  lazada               100
# 100  ClassTransformationModel  exps/lazada/100/103  lazada               100
# 101  ClassTransformationModel  exps/lazada/100/104  lazada               100
# 102  ClassTransformationModel  exps/lazada/100/105  lazada               100
#
#      Latency (ms)  Binary Size (MB)  AUUC (test)  Precision@5  Precision@10  \
# 0        0.059281          3.112857     0.536919     0.009425      0.009378
# 1        0.056143         25.315657     0.701555     0.001197      0.008309
# 2        0.057361         29.465457     0.695790     0.009794      0.010686
# 3        0.057964          4.878569     0.656579     0.011354      0.010685
# 4        0.056108          0.150800     0.478659     0.016890      0.009386
# ..            ...               ...          ...          ...           ...
# 98       0.112837          5.246243     0.521458     0.001763      0.006866
# 99       0.040759          0.061043     0.270447     0.000463     -0.000636
# 100      0.040985         13.127252     0.283212     0.000544      0.001069
# 101      0.039428          1.322932     0.271519    -0.000864      0.000433
# 102      0.039581          0.118772     0.264293     0.000131      0.000694
#
#      Precision@15  Precision@20  Precision@25  Precision@50 Compressions
# 0        0.007088      0.009378      0.006507      0.004036           {}
# 1        0.008484      0.008309      0.007162      0.005920           {}
# 2        0.008920      0.010686      0.009760      0.005464           {}
# 3        0.009732      0.010685      0.008134      0.005860           {}
# 4        0.007613      0.009386      0.005876      0.003602           {}
# ..            ...           ...           ...           ...          ...
# 98       0.005922      0.006866      0.006378      0.004902           {}
# 99       0.000404     -0.000636      0.000532      0.002035           {}
# 100      0.001156      0.001069      0.001054      0.001691           {}
# 101      0.000770      0.000433      0.000452      0.001726           {}
# 102      0.000733      0.000694      0.001249      0.001358           {}
#
# [103 rows x 14 columns]

# %%
# table.sort_values(by=['Precision@5'], ascending=False)

# %%
from src.models.ScikitML.Models import ClassTransformationModel
path = pd.read_csv(BASE_PATH / "exps/stats.tsv", sep='\t').Path.iloc[-1]
model = ClassTransformationModel(from_load=True, path = str(BASE_PATH) + "/" + path)
# Out:
# Model loaded from /Users/ogrobertino/UpliftModelingResearch/exps/lazada/100/105/model.pkl.
# Config loaded from /Users/ogrobertino/UpliftModelingResearch/exps/lazada/100/105/config.json.

# %%
predicted = pd.read_csv(str(BASE_PATH) + "/" + path + "/predictions.tsv", sep='\t')

# %%
predicted.sort_values(by='score')
# Out:
#            score  treatment  target
# 1124   -0.994788          1       0
# 9797   -0.994788          1       0
# 167591 -0.984740          1       0
# 167670 -0.984157          1       0
# 7928   -0.981281          0       0
# ...          ...        ...     ...
# 98158   0.996837          0       0
# 84837   0.996837          0       0
# 16032   0.996856          0       0
# 104277  0.997461          0       0
# 38103   0.997875          0       0
#
# [181669 rows x 3 columns]

# %%
good_preds = predicted[predicted.treatment == predicted.target]

# %%
from src.metric import get_auuc, uplift_by_percentile_CUM
uplift_precision = uplift_by_percentile_CUM(predicted['target'], predicted["score"],
                                                predicted['treatment'], strategy='overall', bins=20)

# %%
uplift_precision
# Out:
#             n_treatment  n_control  response_rate_treatment  \
# percentile
# 5                  4583       4501                 0.005019
# 10                 9437       8731                 0.005086
# 15                14134      13118                 0.005802
# 20                18867      17469                 0.006572
# 25                23555      21865                 0.006920
# 30                28345      26159                 0.007409
# 35                33056      30532                 0.008228
# 40                37697      34975                 0.008781
# 45                42430      39326                 0.009309
# 50                47163      43676                 0.010517
# 55                51891      48031                 0.011775
# 60                56593      52412                 0.012740
# 65                61282      56806                 0.014376
# 70                66005      61166                 0.017650
# 75                70726      65528                 0.020586
# 80                75490      69847                 0.025089
# 85                80298      74122                 0.029067
# 90                85163      78340                 0.032432
# 95                89922      82664                 0.035053
# 100               94682      86987                 0.036998
#
#             response_rate_control    uplift
# percentile
# 5                        0.004888  0.000131
# 10                       0.004810  0.000276
# 15                       0.005107  0.000694
# 20                       0.005839  0.000733
# 25                       0.005671  0.001249
# 30                       0.006728  0.000681
# 35                       0.007075  0.001154
# 40                       0.007691  0.001089
# 45                       0.008341  0.000969
# 50                       0.009158  0.001358
# 55                       0.009931  0.001844
# 60                       0.011104  0.001636
# 65                       0.012710  0.001666
# 70                       0.016136  0.001514
# 75                       0.018679  0.001907
# 80                       0.022535  0.002554
# 85                       0.026672  0.002394
# 90                       0.029704  0.002728
# 95                       0.031852  0.003201
# 100                      0.033258  0.003740

# %%
uplift_precision
# Out:
#             n_treatment  n_control  response_rate_treatment  \
# percentile
# 5                  4583       4501                 0.005019
# 10                 9437       8731                 0.005086
# 15                14134      13118                 0.005802
# 20                18867      17469                 0.006572
# 25                23555      21865                 0.006920
# 30                28345      26159                 0.007409
# 35                33056      30532                 0.008228
# 40                37697      34975                 0.008781
# 45                42430      39326                 0.009309
# 50                47163      43676                 0.010517
# 55                51891      48031                 0.011775
# 60                56593      52412                 0.012740
# 65                61282      56806                 0.014376
# 70                66005      61166                 0.017650
# 75                70726      65528                 0.020586
# 80                75490      69847                 0.025089
# 85                80298      74122                 0.029067
# 90                85163      78340                 0.032432
# 95                89922      82664                 0.035053
# 100               94682      86987                 0.036998
#
#             response_rate_control    uplift
# percentile
# 5                        0.004888  0.000131
# 10                       0.004810  0.000276
# 15                       0.005107  0.000694
# 20                       0.005839  0.000733
# 25                       0.005671  0.001249
# 30                       0.006728  0.000681
# 35                       0.007075  0.001154
# 40                       0.007691  0.001089
# 45                       0.008341  0.000969
# 50                       0.009158  0.001358
# 55                       0.009931  0.001844
# 60                       0.011104  0.001636
# 65                       0.012710  0.001666
# 70                       0.016136  0.001514
# 75                       0.018679  0.001907
# 80                       0.022535  0.002554
# 85                       0.026672  0.002394
# 90                       0.029704  0.002728
# 95                       0.031852  0.003201
# 100                      0.033258  0.003740

# %%
model.model.estimator
# Out:
# True
