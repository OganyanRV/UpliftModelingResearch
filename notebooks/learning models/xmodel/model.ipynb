# %% [markdown]
# ## Xmodeling

# %% [markdown]
# https://habr.com/ru/companies/ru_mts/articles/485980/
# https://habr.com/ru/companies/glowbyte/articles/686398/
# https://causalml.readthedocs.io/en/latest/methodology.html#s-learner
# https://github.com/uber/causalml/tree/master/causalml/inference/meta

# %% [markdown]
# For debug

# %%
# from src.utils import get_paths_train_test, train_test_model
# from src.factory import XModelFactory
# from src.configs_generation import generate_random_configs_xmodel
# from tqdm import tqdm
# configs = generate_random_configs_xmodel(parameters, count=1)
# ds_name = 'lazada'
# features_percent = 50
# factory = XModelFactory
# config = configs[0]
# batch_size=32
# max_size=100000
# train_path, test_path = get_paths_train_test(ds_name=ds_name, features_percent=features_percent)
# model, train, test = factory.create(config, train_path, test_path)

# %%
import logging
logging.basicConfig(level=logging.WARNING)

# %% [markdown]
# propensity = 0.5 ставлю так как уже проверял в другом ноутбуке с анализом, что тритмент и контроль группы стат значимо не различаются

# %%
from pathlib import Path
import sys
 
if sys.argv:
    sys.path.insert(0, str(Path('/Users/ogrobertino/UpliftModelingResearch/').resolve()))
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
parameters = {
    'iterations': (50, 120),
    'learning_rate': (0.01, 0.5),
    'depth': (4, 15)
}

# %%
from src.utils import get_paths_train_test, train_test_model
from src.factory import XModelFactory
from src.configs_generation import generate_random_configs_xmodel
from tqdm import tqdm

configs = generate_random_configs_xmodel(parameters, count=20)

for i in tqdm(range(len(configs)), desc="Training models"):
    train_test_model(ds_name='lazada', features_percent=100, factory=XModelFactory, config=configs[i])
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Training models:   0%|                                   | 0/20 [00:00<?, ?it/s]
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/35
# Training models:   5%|█▎                         | 1/20 [01:03<20:10, 63.72s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/36
# Training models:  10%|██▋                        | 2/20 [02:33<23:37, 78.76s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/37
# Training models:  15%|████                       | 3/20 [03:37<20:31, 72.44s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/38
# Training models:  20%|█████▍                     | 4/20 [05:02<20:34, 77.15s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/39
# Training models:  25%|██████▊                    | 5/20 [06:04<17:58, 71.90s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/40
# Training models:  30%|████████                   | 6/20 [07:07<16:03, 68.82s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/41
# Training models:  35%|█████████▍                 | 7/20 [08:25<15:31, 71.62s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/42
# Training models:  40%|██████████▊                | 8/20 [09:27<13:44, 68.73s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/43
# Training models:  45%|███████████▋              | 9/20 [13:57<24:07, 131.56s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/44
# Training models:  50%|████████████▌            | 10/20 [15:53<21:08, 126.87s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/45
# Training models:  55%|█████████████▊           | 11/20 [19:01<21:50, 145.63s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/46
# Training models:  60%|███████████████          | 12/20 [20:22<16:47, 125.94s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/47
# Training models:  65%|████████████████▎        | 13/20 [22:38<15:02, 128.96s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/48
# Training models:  70%|█████████████████▌       | 14/20 [26:28<15:56, 159.49s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/49
# Training models:  75%|██████████████████▊      | 15/20 [29:17<13:30, 162.13s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/50
# Training models:  80%|████████████████████     | 16/20 [30:21<08:51, 132.84s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/51
# Training models:  85%|█████████████████████▎   | 17/20 [32:16<06:21, 127.29s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/52
# Training models:  90%|██████████████████████▌  | 18/20 [35:08<04:41, 140.86s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/53
# Training models:  95%|███████████████████████▊ | 19/20 [36:10<01:57, 117.16s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps/lazada/100/54
# Training models: 100%|█████████████████████████| 20/20 [38:44<00:00, 116.21s/it]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps/stats.tsv

# %%
from src.global_params import BASE_PATH
import pandas as pd
table = pd.read_csv(BASE_PATH / "exps/stats.tsv", sep='\t')

# %%
table.sort_values(by=['Precision@10'], ascending=False)
# Out:
#      Model                Path Dataset  Features Percent  Latency (ms)  \
# 15  XModel  exps/lazada/100/15  lazada               100      0.024685
# 13  TModel  exps/lazada/100/13  lazada               100      0.058156
# 9   TModel   exps/lazada/100/9  lazada               100      0.057034
# 39  XModel  exps/lazada/100/42  lazada               100      0.034936
# 29  XModel  exps/lazada/100/32  lazada               100      0.034628
# 2   TModel   exps/lazada/100/2  lazada               100      0.057361
# 3   TModel   exps/lazada/100/3  lazada               100      0.057964
# 19  XModel  exps/lazada/100/19  lazada               100      0.024408
# 21  TModel  exps/lazada/100/21  lazada               100      0.057214
# 37  XModel  exps/lazada/100/40  lazada               100      0.034956
# 41  XModel  exps/lazada/100/44  lazada               100      0.035213
# 32  XModel  exps/lazada/100/35  lazada               100      0.035435
# 31  XModel  exps/lazada/100/34  lazada               100      0.035406
# 4   TModel   exps/lazada/100/4  lazada               100      0.056108
# 0   TModel   exps/lazada/100/0  lazada               100      0.059281
# 10  TModel  exps/lazada/100/10  lazada               100      0.056558
# 36  XModel  exps/lazada/100/39  lazada               100      0.034859
# 28  XModel  exps/lazada/100/31  lazada               100      0.036903
# 18  XModel  exps/lazada/100/18  lazada               100      0.025782
# 26  XModel  exps/lazada/100/29  lazada               100      0.035908
# 7   TModel   exps/lazada/100/7  lazada               100      0.055492
# 47  XModel  exps/lazada/100/50  lazada               100      0.034683
# 17  XModel  exps/lazada/100/17  lazada               100      0.025201
# 1   TModel   exps/lazada/100/1  lazada               100      0.056143
# 50  XModel  exps/lazada/100/53  lazada               100      0.034830
# 33  XModel  exps/lazada/100/36  lazada               100      0.035179
# 16  XModel  exps/lazada/100/16  lazada               100      0.025998
# 5   TModel   exps/lazada/100/5  lazada               100      0.057290
# 38  XModel  exps/lazada/100/41  lazada               100      0.034890
# 24  TModel  exps/lazada/100/27  lazada               100      0.055097
# 22  XModel  exps/lazada/100/25  lazada               100      0.034494
# 14  XModel  exps/lazada/100/14  lazada               100      0.025047
# 20  TModel  exps/lazada/100/20  lazada               100      0.056905
# 44  XModel  exps/lazada/100/47  lazada               100      0.035203
# 42  XModel  exps/lazada/100/45  lazada               100      0.034897
# 49  XModel  exps/lazada/100/52  lazada               100      0.036651
# 12  TModel  exps/lazada/100/12  lazada               100      0.057819
# 11  TModel  exps/lazada/100/11  lazada               100      0.058846
# 34  XModel  exps/lazada/100/37  lazada               100      0.034681
# 23  TModel  exps/lazada/100/26  lazada               100      0.054514
# 30  XModel  exps/lazada/100/33  lazada               100      0.036015
# 43  XModel  exps/lazada/100/46  lazada               100      0.035349
# 6   TModel   exps/lazada/100/6  lazada               100      0.058309
# 6          17.388096     0.449403     0.010904      0.005254      0.003474
# 27          2.595840     0.482469     0.014119      0.005156      0.005406
# 51         64.790360     0.426758     0.003727      0.004805      0.005253
# 46         72.921312     0.448551     0.006477      0.004469      0.004977
# 35         10.460312     0.409900     0.007029      0.004290      0.004883
# 25         46.533816     0.467677     0.004994      0.004119      0.004880
# 40        160.557312     0.443027    -0.002335      0.003888      0.004387
# 8          12.526577     0.491589    -0.001493      0.003126      0.004580
# 48         39.019128     0.342853    -0.000812      0.002084      0.002822
# 45        113.930391     0.353096     0.003569      0.001362      0.002104
#
#     Precision@20  Precision@25  Precision@50 Compressions
# 15      0.012347      0.009235      0.005516           {}
# 13      0.011564      0.008356      0.004562           {}
# 9       0.011393      0.008308      0.005581           {}
# 39      0.011062      0.008862      0.005329           {}
# 29      0.010963      0.008805      0.005621           {}
# 2       0.010686      0.009760      0.005464           {}
# 3       0.010685      0.008134      0.005860           {}
# 19      0.010526      0.010035      0.006335           {}
# 21      0.010255      0.009363      0.006447           {}
# 37      0.010149      0.006906      0.005740           {}
# 41      0.009799      0.006500      0.004809           {}
# 32      0.009536      0.008695      0.004952           {}
# 31      0.009470      0.009801      0.004459           {}
# 4       0.009386      0.005876      0.003602           {}
# 0       0.009378      0.006507      0.004036           {}
# 10      0.009339      0.007585      0.004577           {}
# 36      0.009043      0.007454      0.005703           {}
# 28      0.008952      0.007729      0.005272           {}
# 18      0.008684      0.006790      0.004981           {}
# 26      0.008503      0.006820      0.004563           {}
# 7       0.008495      0.008107      0.005221           {}
# 47      0.008434      0.007485      0.004933           {}
# 17      0.008315      0.006661      0.005295           {}
# 1       0.008309      0.007162      0.005920           {}
# 50      0.008301      0.009493      0.005635           {}
# 33      0.008046      0.005344      0.004180           {}
# 16      0.007852      0.005878      0.003756           {}
# 5       0.007774      0.005597      0.004509           {}
# 38      0.007663      0.006348      0.004689           {}
# 24      0.007448      0.007045      0.005361           {}
# 22      0.006961      0.007633      0.005312           {}
# 14      0.006913      0.009136      0.004787           {}
# 20      0.006912      0.007201      0.005649           {}
# 44      0.006763      0.005351      0.003553           {}
# 42      0.006670      0.004889      0.004819           {}
# 49      0.006628      0.005649      0.004060           {}
# 12      0.006605      0.007063      0.004343           {}
# 11      0.006432      0.005947      0.003126           {}
# 34      0.006347      0.005973      0.004009           {}
# 23      0.006073      0.006034      0.004499           {}
# 30      0.005555      0.005580      0.004185           {}
# 43      0.005441      0.003965      0.003910           {}
# 6       0.005254      0.004186      0.004041           {}
# 27      0.005156      0.004961      0.004167           {}
# 51      0.004805      0.004070      0.003145           {}
# 46      0.004469      0.004085      0.003967           {}
# 35      0.004290      0.005226      0.002424           {}
# 25      0.004119      0.005267      0.003197           {}
# 40      0.003888      0.004033      0.003238           {}
# 8       0.003126      0.006341      0.004382           {}
# 48      0.002084      0.003164      0.002776           {}
# 45      0.001362      0.003236      0.002608           {}

# %%
from src.models.ICausalML.Models import XModel
path = pd.read_csv(BASE_PATH / "exps/stats.tsv", sep='\t').Path.iloc[-1]
model = XModel(from_load=True, path = str(BASE_PATH) + "/" + path)
