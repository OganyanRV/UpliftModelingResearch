# %%
# !pip install -r ../requirements.txt

# %%
import pathlib
import os
script_path = str(pathlib.Path(os.path.dirname(os.path.abspath("")))) + "/src/run_train.py"

# %%
from pathlib import Path
import sys
 
if sys.argv:
    sys.path.insert(0, str(Path(BASE_PATH).resolve()))
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.global_params import *

from src.utils import get_paths_train_test, train_test_model
from src.factory import TModelFactory
from src.models.CausalML.Models import TModel
from tqdm import tqdm
from src import run_train

# %%
BASE_PATH
# Out:
# '/home/ogrobertino/UpliftModelingResearch'

# %%
# !python {script_path} --count 20 --ds_name "lazada_v2_opt" --features_percent 100 --model "TModel" --iterations 20 50 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# /home/ogrobertino/test_env/lib/python3.10/site-packages/xgboost/core.py:377: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc >= 2.28) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(
# Failed to import duecredit due to No module named 'duecredit'
# Training models:   0%|                                   | 0/20 [00:00<?, ?it/s]Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/0
# Эксперимент сохранен в таблице /home/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 50 --model "TModel" --iterations 40 80 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/10s]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/11t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/12t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/13t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/14t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 100 --model "SModel" --iterations 20 50 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/39]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/40]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/41]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/42]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/43]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 50 --model "SModel" --iterations 40 80 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/30s]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/31t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/32t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/33t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/34t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 100 --model "XModel" --iterations 20 50 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/59]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/60]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/61]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/62]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/63]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 50 --model "XModel" --iterations 40 80 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/50s]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/51t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/52t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/53t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/54t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 100 --model "DRModel" --iterations 20 50 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/79]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/80]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/81]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/82]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/83]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 50 --model "DRModel" --iterations 40 80 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/70s]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/71t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/72t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/73t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/74t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 100 --model "ClassTransformationModel" --iterations 20 50 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/99]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/100
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/101
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/102
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/103
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 50 --model "ClassTransformationModel" --iterations 40 80 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/90s]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/91t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/92t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/93t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/94t]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 100 --model "ClassTransformationRegModel" --iterations 20 50 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/119
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/120
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/121
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/122
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/123
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 50 --model "ClassTransformationRegModel" --iterations 40 80 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/110]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/111]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/112]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/113]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/114]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 100 --model "UpliftRandomForestModel" --n_estimators 20 60 --max_depth 10 100 --min_samples_leaf 50 150 --n_reg 1 100
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/150
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/151
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/152
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/153
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/154
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 10 --ds_name "lazada_v2_opt" --features_percent 50 --model "UpliftRandomForestModel" --n_estimators 50 120 --max_depth 10 100 --min_samples_leaf 50 150 --n_reg 1 100
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/141]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/142]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/143]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/144]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/50/145]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %% [markdown]
# хз попробую полегче

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 20 --ds_name "lazada_v2_opt" --features_percent 100 --model "UpliftRandomForestModel" --n_estimators 5 20 --max_depth 10 100 --min_samples_leaf 50 150 --n_reg 1 100
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/170
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/171
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/172
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/173
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/174
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 1 --ds_name "lazada_v2_opt" --features_percent 100 --model "SModel" --iterations 30 70 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/16]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Training models: 100%|████████████████████████████| 1/1 [00:06<00:00,  6.83s/it]

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 1 --ds_name "lazada_v2_opt" --features_percent 100 --model "XModel" --iterations 30 70 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/17]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Training models: 100%|████████████████████████████| 1/1 [00:28<00:00, 28.18s/it]

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 1 --ds_name "lazada_v2_opt" --features_percent 100 --model "DRModel" --iterations 30 70 --learning_rate 0.01 0.5 --depth 4 15
# Out:
# Failed to import duecredit due to No module named 'duecredit'
# Модель, предсказания и конфиг сохранены в директории exps2/lazada_v2_opt/100/18]
# Эксперимент сохранен в таблице /Users/ogrobertino/UpliftModelingResearch/exps2/stats.tsv
# Training models: 100%|████████████████████████████| 1/1 [00:40<00:00, 40.62s/it]

# %%
from src.global_params import BASE_PATH
import pandas as pd
table = pd.read_csv(BASE_PATH + "/" + EXPS_PATH +  "/stats.tsv", sep='\t')
# table[table['Model'] == 'TModel'].sort_values(["AUUC"], ascending=False)

# %%
table.sort_values(["AUUC"], ascending=False).head(40)
# Out:
#                        Model                         Path        Dataset  \
# 292  UpliftRandomForestModel  exps2/lazada_v2_opt/100/162  lazada_v2_opt
# 289  UpliftRandomForestModel  exps2/lazada_v2_opt/100/159  lazada_v2_opt
# 272  UpliftRandomForestModel  exps2/lazada_v2_opt/100/142  lazada_v2_opt
# 270  UpliftRandomForestModel  exps2/lazada_v2_opt/100/140  lazada_v2_opt
# 291  UpliftRandomForestModel  exps2/lazada_v2_opt/100/161  lazada_v2_opt
# 279  UpliftRandomForestModel  exps2/lazada_v2_opt/100/149  lazada_v2_opt
# 287  UpliftRandomForestModel  exps2/lazada_v2_opt/100/157  lazada_v2_opt
# 274  UpliftRandomForestModel  exps2/lazada_v2_opt/100/144  lazada_v2_opt
# 273  UpliftRandomForestModel  exps2/lazada_v2_opt/100/143  lazada_v2_opt
# 296  UpliftRandomForestModel  exps2/lazada_v2_opt/100/166  lazada_v2_opt
# 297  UpliftRandomForestModel  exps2/lazada_v2_opt/100/167  lazada_v2_opt
# 276  UpliftRandomForestModel  exps2/lazada_v2_opt/100/146  lazada_v2_opt
# ...

# %%
# !python /Users/ogrobertino/UpliftModelingResearch/src/run_train.py --count 1 --ds_name "lazada_v2_opt" --features_percent 100 --model "DRModel" --iterations 30 70 --learning_rate 0.01 0.5 --depth 4 15
